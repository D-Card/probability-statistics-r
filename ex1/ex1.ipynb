# %%
library('openxlsx')
df1 <- read.xlsx(xlsxFile = 'ResiduosPerCapita.xlsx', sheet = 1, rows = 12:43, cols = 1:3)
names(df1) <- c("País", "2004", "2018")
df1
# Out:
#    País                                         2004 2018
# 1  UE27 (2020) - União Europeia 27 (desde 2020)  5.2  5.2
# 2  DE - Alemanha                                 4.4  4.9
# 3  AT - Áustria                                  6.5  7.4
# 4  BE - Bélgica                                  5.1  5.9
# 5  BG - Bulgária                                26.0 18.5
# 6  CY - Chipre                                   3.1  2.6
# 7  HR - Croácia                                  1.7  1.4
# 8  DK - Dinamarca                                2.3  3.7
# 9  SK - Eslováquia                               2.0  2.3
# 10 SI - Eslovénia                                2.9  4.0
# 11 ES - Espanha                                  3.7  2.9
# 12 EE - Estónia                                 15.3 17.5
# 13 FI - Finlândia                               13.3 23.2
# 14 FR - França                                   4.7  5.1
# 15 GR - Grécia                                   3.0  4.2
# 16 HU - Hungria                                  2.4  1.9
# 17 IE - Irlanda                                  6.0  2.9
# 18 IT - Itália                                   2.4  2.9
# 19 LV - Letónia                                  0.6  0.9
# 20 LT - Lituânia                                 2.1  2.5
# 21 LU - Luxemburgo                              18.2 14.8
# 22 MT - Malta                                    7.8  5.2
# 23 NL - Países Baixos                            5.7  8.4
# 24 PL - Polónia                                  3.6  4.6
# 25 PT - Portugal                                 2.8  1.5
# 26 CZ - República Checa                          2.9  2.6
# 27 RO - Roménia                                 17.2 10.4
# 28 SE - Suécia                                  10.2 13.6
# 29 IS - Islândia                                 1.7  3.7
# 30 NO - Noruega                                  1.6  2.7
# 31 UK - Reino Unido                              5.0  4.2

# %%
library("tidyr")
df1_tidy <- df1 %>%
  pivot_longer(c("2004", "2018"), names_to = "Ano", values_to = "Resíduos")
df1_tidy
# Out:
#    País                                         Ano  Resíduos
# 1  UE27 (2020) - União Europeia 27 (desde 2020) 2004  5.2
# 2  UE27 (2020) - União Europeia 27 (desde 2020) 2018  5.2
# 3  DE - Alemanha                                2004  4.4
# 4  DE - Alemanha                                2018  4.9
# 5  AT - Áustria                                 2004  6.5
# 6  AT - Áustria                                 2018  7.4
# 7  BE - Bélgica                                 2004  5.1
# 8  BE - Bélgica                                 2018  5.9
# 9  BG - Bulgária                                2004 26.0
# 10 BG - Bulgária                                2018 18.5
# 11 CY - Chipre                                  2004  3.1
# 12 CY - Chipre                                  2018  2.6
# 13 HR - Croácia                                 2004  1.7
# 14 HR - Croácia                                 2018  1.4
# 15 DK - Dinamarca                               2004  2.3
# 16 DK - Dinamarca                               2018  3.7
# 17 SK - Eslováquia                              2004  2.0
# 18 SK - Eslováquia                              2018  2.3
# 19 SI - Eslovénia                               2004  2.9
# 20 SI - Eslovénia                               2018  4.0
# 21 ES - Espanha                                 2004  3.7
# 22 ES - Espanha                                 2018  2.9
# 23 EE - Estónia                                 2004 15.3
# 24 EE - Estónia                                 2018 17.5
# 25 FI - Finlândia                               2004 13.3
# 26 FI - Finlândia                               2018 23.2
# 27 FR - França                                  2004  4.7
# 28 FR - França                                  2018  5.1
# 29 GR - Grécia                                  2004  3.0
# 30 GR - Grécia                                  2018  4.2
# ⋮  ⋮                                            ⋮    ⋮
# 33 IE - Irlanda                                 2004  6.0
# 34 IE - Irlanda                                 2018  2.9
# 35 IT - Itália                                  2004  2.4
# 36 IT - Itália                                  2018  2.9
# 37 LV - Letónia                                 2004  0.6
# 38 LV - Letónia                                 2018  0.9
# 39 LT - Lituânia                                2004  2.1
# 40 LT - Lituânia                                2018  2.5
# 41 LU - Luxemburgo                              2004 18.2
# 42 LU - Luxemburgo                              2018 14.8
# 43 MT - Malta                                   2004  7.8
# 44 MT - Malta                                   2018  5.2
# 45 NL - Países Baixos                           2004  5.7
# 46 NL - Países Baixos                           2018  8.4
# 47 PL - Polónia                                 2004  3.6
# 48 PL - Polónia                                 2018  4.6
# 49 PT - Portugal                                2004  2.8
# 50 PT - Portugal                                2018  1.5
# 51 CZ - República Checa                         2004  2.9
# 52 CZ - República Checa                         2018  2.6
# 53 RO - Roménia                                 2004 17.2
# 54 RO - Roménia                                 2018 10.4
# 55 SE - Suécia                                  2004 10.2
# 56 SE - Suécia                                  2018 13.6
# 57 IS - Islândia                                2004  1.7
# 58 IS - Islândia                                2018  3.7
# 59 NO - Noruega                                 2004  1.6
# 60 NO - Noruega                                 2018  2.7
# 61 UK - Reino Unido                             2004  5.0
# 62 UK - Reino Unido                             2018  4.2

# %%
library("dplyr")
df1_final <- df1_tidy %>%  
filter(País %in% c("CY - Chipre", "IE - Irlanda", "IS - Islândia"))
df1_final
# Out:
#   País          Ano  Resíduos
# 1 CY - Chipre   2004 3.1
# 2 CY - Chipre   2018 2.6
# 3 IE - Irlanda  2004 6.0
# 4 IE - Irlanda  2018 2.9
# 5 IS - Islândia 2004 1.7
# 6 IS - Islândia 2018 3.7

# %%
library("ggplot2")
df1_plot <- ggplot(df1_final, aes(x = País, y = Resíduos, fill = Ano)) + geom_col(position = "dodge") +
geom_text(aes(label = Resíduos), size = 6, vjust = 1.5, colour = "white", position = position_dodge(0.9))

# %%
df1_plotfinal <- df1_plot +labs(x = "País", y = "Resíduos (ton)", title = "Produção de resíduos per capita", caption = "Baseado em ResiduosPerCapita.xlsx") + 
 theme(axis.text.x = element_text(angle = 20, size = 12), axis.text.y = element_text(size = 12), plot.title = element_text(size = 18, face ="bold"))
df1_plotfinal
ggsave("ResiduosPerCapita.png", df1_plotfinal)
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
