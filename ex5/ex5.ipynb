# %%
library(ggplot2)
set.seed(894)
df1 <- data.frame(
    values = c(rexp(531, 0.42))
)
ggplot(df1, aes(x = values)) +
    geom_density()
teórico <- 1 - pexp(2, rate = 0.42)
teórico
empírico <- 1 - ecdf(df1$values)(2)
empírico
abs(empírico - teórico)
# Out:
# [1] 0.4317105
# [1] 0.4237288
# [1] 0.00798171
# plot without title
